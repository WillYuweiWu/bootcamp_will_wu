# %% [markdown]
# # Stage 05 - Data Storage

# %%
import os, pathlib, datetime as dt
import pandas as pd
from dotenv import load_dotenv

load_dotenv()
RAW = pathlib.Path(os.getenv('DATA_DIR_RAW', '../data/raw'))
PROC = pathlib.Path(os.getenv('DATA_DIR_PROCESSED', '../data/processed'))
RAW.mkdir(parents = True, exist_ok = True)
PROC.mkdir(parents = True, exist_ok = True)
print('RAW ->', RAW.resolve())
print('PROC ->', PROC.resolve())
# Out:
# RAW -> /Users/willwu/Desktop/NYU Tandon/FRE-GY/5040 Foundations of Applied Financial Engineering/bootcamp_will_wu/project/data/raw
# PROC -> /Users/willwu/Desktop/NYU Tandon/FRE-GY/5040 Foundations of Applied Financial Engineering/bootcamp_will_wu/project/data/processed

# %%
import numpy as np
df = pd.read_csv('../data/raw/VIX_S&P500_raw.csv')
df.head()
# Out:
#          date           vix_close            vix_high             vix_low  \
# 0         NaN                ^VIX                ^VIX                ^VIX
# 1  2019-08-28  19.350000381469727  21.639999389648438  19.100000381469727
# 2  2019-08-29    17.8799991607666  19.200000762939453  17.600000381469727
# 3  2019-08-30  18.979999542236328   19.18000030517578   17.09000015258789
# 4  2019-09-03   19.65999984741211  21.149999618530273   19.40999984741211
#
#              vix_open vix_volume       sp500_close         sp500_high  \
# 0                ^VIX       ^VIX             ^GSPC              ^GSPC
# 1  20.549999237060547          0  2887.93994140625  2890.030029296875
# 2  19.020000457763672          0    2924.580078125             2930.5
# 3  17.940000534057617          0   2926.4599609375  2940.429931640625
# 4  20.959999084472656          0  2906.27001953125  2914.389892578125
#
#            sp500_low         sp500_open sp500_volume
# 0              ^GSPC              ^GSPC        ^GSPC
# 1  2853.050048828125  2861.280029296875   3102480000
# 2     2905.669921875    2910.3701171875   3177150000
# 3  2913.320068359375  2937.090087890625   3009910000
# 4   2891.85009765625  2909.010009765625   3427830000

# %%
# Save processed data

df = df.drop(index = 0)
df.head()
# Out:
#          date           vix_close            vix_high             vix_low  \
# 1  2019-08-28  19.350000381469727  21.639999389648438  19.100000381469727
# 2  2019-08-29    17.8799991607666  19.200000762939453  17.600000381469727
# 3  2019-08-30  18.979999542236328   19.18000030517578   17.09000015258789
# 4  2019-09-03   19.65999984741211  21.149999618530273   19.40999984741211
# 5  2019-09-04  17.329999923706055  18.829999923706055  17.260000228881836
#
#              vix_open vix_volume        sp500_close         sp500_high  \
# 1  20.549999237060547          0   2887.93994140625  2890.030029296875
# 2  19.020000457763672          0     2924.580078125             2930.5
# 3  17.940000534057617          0    2926.4599609375  2940.429931640625
# 4  20.959999084472656          0   2906.27001953125  2914.389892578125
# 5  18.229999542236328          0  2937.780029296875  2938.840087890625
#
#            sp500_low         sp500_open sp500_volume
# 1  2853.050048828125  2861.280029296875   3102480000
# 2     2905.669921875    2910.3701171875   3177150000
# 3  2913.320068359375  2937.090087890625   3009910000
# 4   2891.85009765625  2909.010009765625   3427830000
# 5  2921.860107421875     2924.669921875   3167900000

# %%
df.to_csv('../data/raw/VIX_S&P500_raw.csv', index = False)

# %%
# Save Parquet to data/processed

# %pip install pyarrow
# %pip install fastparquet

def ts(): return dt.datetime.now().strftime('%Y%m%d-%H%M%S')

pq_path = PROC / f"sample_{ts()}.parquet"
try:
    df.to_parquet(pq_path)
except Exception as e:
    print('Parquet engine not available. Install pyarrow or fastparquet to complete this step.')
    pq_path = None
pq_path
# Out:
# Requirement already satisfied: pyarrow in /Users/willwu/anaconda3/lib/python3.10/site-packages (21.0.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: fastparquet in /Users/willwu/anaconda3/lib/python3.10/site-packages (2024.11.0)
# Requirement already satisfied: fsspec in /Users/willwu/anaconda3/lib/python3.10/site-packages (from fastparquet) (2022.11.0)
# Requirement already satisfied: numpy in /Users/willwu/anaconda3/lib/python3.10/site-packages (from fastparquet) (1.23.5)
# Requirement already satisfied: pandas>=1.5.0 in /Users/willwu/anaconda3/lib/python3.10/site-packages (from fastparquet) (1.5.3)
# Requirement already satisfied: packaging in /Users/willwu/anaconda3/lib/python3.10/site-packages (from fastparquet) (22.0)
# Requirement already satisfied: cramjam>=2.3 in /Users/willwu/anaconda3/lib/python3.10/site-packages (from fastparquet) (2.11.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/willwu/anaconda3/lib/python3.10/site-packages (from pandas>=1.5.0->fastparquet) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/willwu/anaconda3/lib/python3.10/site-packages (from pandas>=1.5.0->fastparquet) (2022.7)
# Requirement already satisfied: six>=1.5 in /Users/willwu/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas>=1.5.0->fastparquet) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# PosixPath('../data/processed/sample_20250827-221639.parquet')
